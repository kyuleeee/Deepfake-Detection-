# %%
# !pip install -q face-recognition==1.3.0 albumentations==1.3.0 decord==0.6.0 timm==0.6.5 opencv-python
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 132.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.8/512.8 kB 47.2 MB/s eta 0:00:00
#   Building wheel for face-recognition-models (setup.py) ... done

# %%
# model 폴더를 제외하고 모든 파일을 담아 "아카이브.zip" 파일로 구성하여 colab에 업로드 함.
# colab에서 돌리기 위해서는 제공된 "아카이브.zip"을 그대로 업로드하면 됨.
# !unzip -qq "아카이브.zip" -d .

# %%
from huggingface_hub import snapshot_download
import os

repo_id = "Deressa/GenConViT"
local_dir = "/content/model/GenConViT"   # 원하는 경로

os.makedirs(local_dir, exist_ok=True)

# 특정 확장자만 받고 싶으면 allow_patterns에 패턴 추가
# (예: *.pt, *.pth, *.bin, *.safetensors, *.yaml, *.json 등)
downloaded_path = snapshot_download(
    repo_id=repo_id,
    local_dir=local_dir,
    local_dir_use_symlinks=False,          # symlink 대신 실제 파일 복사
    # allow_patterns=["*.pt", "*.pth", "*.bin", "*.safetensors", "*.yaml", "*.json"]
)

print("Saved to:", downloaded_path)
# !ls -al "/content/model/GenConViT"
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:979: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# README.md:   0%|          | 0.00/774 [00:00<?, ?B/s]
# genconvit_vae_inference.pth:   0%|          | 0.00/2.78G [00:00<?, ?B/s]
# genconvit_ed_inference.pth:   0%|          | 0.00/238M [00:00<?, ?B/s]
# Saved to: /content/model/GenConViT
# total 2949596
# drwxr-xr-x 3 root root       4096 Nov  9 08:04 .
# drwxr-xr-x 3 root root       4096 Nov  9 08:04 ..
# drwxr-xr-x 3 root root       4096 Nov  9 08:03 .cache
# -rw-r--r-- 1 root root  238174949 Nov  9 08:04 genconvit_ed_inference.pth
# -rw-r--r-- 1 root root 2782175601 Nov  9 08:04 genconvit_vae_inference.pth
# -rw-r--r-- 1 root root       1519 Nov  9 08:03 .gitattributes
# -rw-r--r-- 1 root root        774 Nov  9 08:03 README.md

# %%
import timm
import torch

bb_name = "convnext_tiny"
bb_path = "model/convnext_tiny.pth"
em_name = "swin_tiny_patch4_window7_224"
em_path = "model/swin_tiny_patch4_window7_224.pth"

em = timm.create_model(em_name, pretrained=True)
torch.save(em.state_dict(), em_path)

bb = timm.create_model(bb_name, pretrained=True)
torch.save(bb.state_dict(), bb_path)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:554: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4322.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Downloading: "https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth" to /root/.cache/torch/hub/checkpoints/swin_tiny_patch4_window7_224.pth
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_tiny_1k_224_ema.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny_1k_224_ema.pth

# %%
# !python3 eval.py
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:554: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4322.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [load_local_weights] Loaded 190 keys (strict)
# [load_local_weights] Loaded 182 keys (strict)
# [GenConViTED] bb=convnext_tiny | em=swin_tiny_patch4_window7_224
# [GenConViTED] bb_ckpt=/content/model/convnext_tiny.pth
# [GenConViTED] em_ckpt=/content/model/swin_tiny_patch4_window7_224.pth
# [load_local_weights] Loaded 190 keys (strict)
# [load_local_weights] Loaded 182 keys (strict)
# [GenConViTVAE] bb=convnext_tiny | em=swin_tiny_patch4_window7_224
# [GenConViTVAE] bb_ckpt=/content/model/convnext_tiny.pth
# [GenConViTVAE] em_ckpt=/content/model/swin_tiny_patch4_window7_224.pth
# Load genconvit network
# Start Evaluating...
# 100% 12/12 [00:38<00:00,  3.21s/it]

# %%
# !zip face_detect_ images.zip face_detect_images/*
# Out:
# 	zip warning: name not matched: images.zip
#   adding: face_detect_images/sample_image_1_detection.png (deflated 0%)
#   adding: face_detect_images/sample_image_2_detection.png (deflated 0%)
#   adding: face_detect_images/sample_image_3_detection.png (deflated 0%)
#   adding: face_detect_images/sample_image_4_detection.png (deflated 0%)
#   adding: face_detect_images/sample_image_5_detection.png (deflated 0%)
#   adding: face_detect_images/sample_image_6_detection.png (deflated 0%)
#   adding: face_detect_images/sample_image_7_detection.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_0.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_10.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_11.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_12.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_13.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_14.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_1.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_2.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_3.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_4.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_5.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_6.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_7.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_8.png (deflated 0%)
#   adding: face_detect_images/sample_video_1_detection_9.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_0.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_10.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_11.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_12.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_13.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_1.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_2.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_3.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_4.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_5.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_6.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_7.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_8.png (deflated 0%)
#   adding: face_detect_images/sample_video_2_detection_9.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_0.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_10.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_11.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_12.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_13.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_1.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_2.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_3.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_4.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_5.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_6.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_7.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_8.png (deflated 0%)
#   adding: face_detect_images/sample_video_3_detection_9.png (deflated 0%)
#   adding: face_detect_images/sample_video_4_detection_0.png (deflated 0%)
#   adding: face_detect_images/sample_video_4_detection_1.png (deflated 0%)
#   adding: face_detect_images/sample_video_4_detection_2.png (deflated 0%)
#   adding: face_detect_images/sample_video_4_detection_3.png (deflated 0%)
#   adding: face_detect_images/sample_video_4_detection_4.png (deflated 0%)
#   adding: face_detect_images/sample_video_4_detection_5.png (deflated 0%)
#   adding: face_detect_images/sample_video_4_detection_6.png (deflated 0%)
#   adding: face_detect_images/sample_video_4_detection_7.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_0.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_10.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_11.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_12.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_13.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_14.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_1.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_2.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_3.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_4.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_5.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_6.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_7.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_8.png (deflated 0%)
#   adding: face_detect_images/sample_video_5_detection_9.png (deflated 0%)
